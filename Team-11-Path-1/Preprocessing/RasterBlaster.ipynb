# %%
# !pip install nbimporter

# %%
import nbimporter
from RasterSlasher import preprocess_dataset
from RasterSmasher import process_raster_patches
paths = {
    "naip": "/home/ec2-user/SageMaker/data/",
    "mask": "/home/ec2-user/SageMaker/data/",
    "hillshade": "/home/ec2-user/SageMaker/data/",
    "dem": "/home/ec2-user/SageMaker/data/"
}

RasterSlasher.preprocess_dataset(
    patch_size=512,
    paths=paths,
    shapefile_path="/home/ec2-user/SageMaker/data/",
    train_dir="/home/ec2-user/SageMaker/data/",
    test_dir="/home/ec2-user/SageMaker/data/"
)
TorT = "test"
# RasterSmasher.process_raster_patches(
#     namingOfNAIP="/home/ec2-user/SageMaker/data/" + TorT + "/images/SCC_NAIP_1m_patch*-*.tif",
#     namingOfDEM="/home/ec2-user/SageMaker/data/" + TorT + "/dem/SCC_dem_patch*-*.tif",
#     namingOfHillshade="/home/ec2-user/SageMaker/data/" + TorT + "/hillshade/SCC_hillshade_patch*-*.tif",
#     namingOfSmashedFile="/home/ec2-user/SageMaker/data/" + TorT + "/smashedData/SCC_smashed_1m_patch*-*.tif",
#     num_cols=25,
#     num_rows=20
# )
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 3
#       1 import nbimporter
#       2 from RasterSlasher import preprocess_dataset
# ----> 3 from RasterSmasher import process_raster_patches
#       4 # paths = {
#       5 #     "naip": "/path/to/NAIP.tif",
#       6 #     "mask": "/path/to/mask.tif",
#    (...)
#      16 #     test_dir="/home/ec2-user/SageMaker/data/"
#      17 # )
#      18 TorT = "test"
#
# ImportError: cannot import name 'process_raster_patches' from 'RasterSmasher' (RasterSmasher.ipynb)
